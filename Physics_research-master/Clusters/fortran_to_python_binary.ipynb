# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
tmp_file_dir = '/storage/cluster/data/tmp/'
file_name = 'sub01d1024'

# %%
tmp = np.fromfile('/storage/cluster/data/tmp/' +  file_name,dtype='float32')

# %%
#processed = tmp[24:]

# %%
os.chdir('/storage/cluster/data/processed_data/')
processed.tofile('test')

# %%
data = np.fromfile('/storage/cluster/data/processed_data/test',dtype='float32')

# %%
len(tmp) - 1024**3
# Out:
# 0

# %%
data_re = tmp.reshape([1024,1024,1024])

# %%
plt.imshow(np.log10(data_re[:,:,0]))

# %%
#os.chdir('/storage/cluster/data/tmp/')
tmp_file_dir = '/storage/cluster/data/tmp/'

for file_name in os.listdir('/storage/cluster/data/tmp/'):
    tmp = np.fromfile('/storage/cluster/data/tmp/' +  file_name,'b')
    processed = tmp[4:-4]
    os.chdir('/storage/cluster/data/processed_data/')
    processed.tofile(file_name)
    print(file_name)

# %%
data = np.fromfile('/storage/cluster/data/processed_data/512fluid+204818a',dtype='float32')

# %%
data_re = data.reshape([512,512,512])

# %%
plt.imshow(np.log10(data_re[0,:,:]))
