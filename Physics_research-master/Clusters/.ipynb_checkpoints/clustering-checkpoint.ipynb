# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import axes3d
from sklearn.cluster import KMeans

# %%
data_dir = '/storage/cluster/data/'
df = pd.read_excel(data_dir + 'data.xlsx')

# %%
df
# Out:
#       Unnamed: 0  number    x    y    z  virial_radius (Mpc)  data_mass (log)  \
# 0              0       8  179  226    3                 1.17        46.254537
# 1              1      10  125  210    4                 1.56        46.634650
# 2              2      11   46  112    4                 1.17        46.049630
# 3              3      12   30  154    4                 1.17        46.091818
# 4              4      13   30  121    4                 0.39        44.847325
# ...          ...     ...  ...  ...  ...                  ...              ...
# 1091        1091    1159  149   31  252                 0.78        45.711489
# 1092        1092    1160   74   79  252                 0.78        45.727725
# 1093        1093    1161  106  105  253                 0.78        45.678832
# 1094        1094    1163  206   51  253                 0.39        44.874593
# 1095        1095    1165  104   55  253                 0.78        45.496465
#
#       xray_weighted_temp(log K)
# 0                      7.973127
# 1                      8.286083
# 2                      7.603048
# 3                      7.774500
# 4                      6.518597
# ...                         ...
# 1091                   7.380387
# 1092                   7.309181
# 1093                   7.293477
# 1094                   6.606520
# 1095                   7.171214
#
# [1096 rows x 8 columns]

# %%
df_array = df.to_numpy()

# %%
coord_x = df_array[:,2]
coord_y = df_array[:,3]
coord_z = df_array[:,4]

# %%
#fig = plt.figure()
#ax = fig.add_subplot(111,projection='3d')
plt.figure(figsize=[10,10])
ax = plt.axes(projection='3d')
ax.scatter(coord_x,coord_y,coord_z,s=5)

# %%
coords = [coord_x,coord_y,coord_z]

# %%
coords
# Out:
# [array([179., 125.,  46., ..., 106., 206., 104.]),
#  array([226., 210., 112., ..., 105.,  51.,  55.]),
#  array([  3.,   4.,   4., ..., 253., 253., 253.])]

# %%
from sklearn.cluster import KMeans
model = Kmeans(n_cluster=3,algorithm='auto')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-4d88bbd16486> in <module>
#       1 from sklearn.cluster import KMeans
# ----> 2 model = Kmeans(n_cluster=3,algorithm='auto').fi
#
# NameError: name 'Kmeans' is not defined

# %%
Kmeans
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b1a98982ea3d> in <module>
# ----> 1 Kmeans
#
# NameError: name 'Kmeans' is not defined
